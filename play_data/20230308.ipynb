# %%
import pandas as pd
import os

# %%
os.listdir("./20230308")
# Out:
# ['concat_2.csv', 'concat_3.csv', 'concat_1.csv']

# %%
dir_path = "./20230308"
for file in os.listdir(dir_path):
    locals()[f'{file}'.split('.')[0]] = pd.read_csv(f"{dir_path}/{file}")

# %%
concat_3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
row_concat = pd.concat([concat_1,concat_2,concat_3])

# %%
temp = pd.DataFrame([['n1','n2','n3','n4']], columns = ['A','B','C','D'])

# %%
df = pd.concat([row_concat,temp],ignore_index=True)

# %%
df.isnull().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# dtype: int64

# %%
df
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11
# 12   n1   n2   n3   n4

# %%
df.iloc[1:3,:]
# Out:
#     A   B   C   D
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.set_index("A")
# Out:
#        B    C    D
# A
# a0    b0   c0   d0
# a1    b1   c1   d1
# a2    b2   c2   d2
# a3    b3   c3   d3
# a4    b4   c4   d4
# a5    b5   c5   d5
# a6    b6   c6   d6
# a7    b7   c7   d7
# a8    b8   c8   d8
# a9    b9   c9   d9
# a10  b10  c10  d10
# a11  b11  c11  d11
# n1    n2   n3   n4

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.columns = ['a','b','c','d']

# %%
df
# Out:
#       a    b    c    d
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11
# 12   n1   n2   n3   n4

# %%
concat_1.columns = ['A', 'B', 'C', 'D']
concat_2.columns = ['E', 'F', 'G', 'H']
concat_3.columns = ['A', 'C', 'F', 'H']

# %%
pd.concat([concat_1,concat_3], ignore_index=True,join='inner')
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 4   a8   b8
# 5   a9   b9
# 6  a10  b10
# 7  a11  b11

# %%
concat_1.index = [0,1,2,3]
concat_2.index = [4,5,6,7]
concat_3.index = [0,2,5,7]

# %%
for file in os.listdir("./20230308"):
    if file.find("sur") > -1:
        locals()[ f'{(file.split(".")[0].split("_")[-1])}'] = pd.read_csv(f"./20230308/{file}")

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
pd.merge(site,visited,left_on='name',right_on='site') # DataFrame Join
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14
